# %% [markdown]
# ## KMeans Using Cereal
# What is going on with the cereal that many people eat every morning for breakfast?  Are there similarities (and maybe even common strategies) across different brands?
#
# The cereal.csv dataset provides information about 77 brands of cereals, including calories, protein, fiber, among others.  The question we will explore is whether the included factors describe *statistical* clusters (as opposed to Honey Bunches of Oats clusters!).
#
# Here is more information from Kaggle.com:
# * Name: Name of cereal
# * mfr: Manufacturer of cereal
#   * A = American Home Food Products;
#   * G = General Mills
#   * K = Kelloggs
#   * N = Nabisco
#   * P = Post
#   * Q = Quaker Oats
#   * R = Ralston Purina
# * type:
#   * cold
#   * hot
# * calories: calories per serving
# * protein: grams of protein
# * fat: grams of fat
# * sodium: milligrams of sodium
# * fiber: grams of dietary fiber
# * carbo: grams of complex carbohydrates
# * sugars: grams of sugars
# * potass: milligrams of potassium
# * vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended
# * shelf: display shelf (1, 2, or 3, counting from the floor)
# * weight: weight in ounces of one serving
# * cups: number of cups in one serving
# * rating: a rating of the cereals (Possibly from Consumer Reports?)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cereal.csv')

# %%
df.head()
# Out:
#                         name mfr  mfrcode type  typecode  calories  protein  \
# 0                  100% Bran   N        4    C         1      70.3      4.3
# 1          100% Natural Bran   Q        6    C         1     120.0      3.0
# 2                   All-Bran   K        3    C         1      70.9      4.9
# 3  All-Bran with Extra Fiber   K        3    C         1      49.3      3.3
# 4             Almond Delight   R        7    C         1     109.6      1.6
#
#    fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0  1.3   130.3   10.3    5.0       6     280        25      3     1.0  0.33
# 1  5.0    15.0    2.0    8.0       8     135         0      3     1.0  1.00
# 2  1.9   260.9    9.9    7.0       5     320        25      3     1.0  0.33
# 3  0.0   139.3   13.3    8.0       0     330        25      3     1.0  0.50
# 4  1.6   199.6    0.6   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
df.shape
# Out:
# (77, 18)

# %% [markdown]
# ### IMPORTANT:
# Note how the scale for calories, protein, fat, etc. are all different?  Calories ranges from 40 or so to 120 or so per serving.  Fat ranges from 0 to around 5.  Not scaling these values would result in biased results, since the cluster algorithm expects the included dimensions to be on the same scale!

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'mfrcode', 'type', 'typecode', 'calories', 'protein',
#        'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins',
#        'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
df2 = df[['fat', 'carbo']].copy()

# %%
df2.head()
# Out:
#    fat  carbo
# 0  1.3    5.0
# 1  5.0    8.0
# 2  1.9    7.0
# 3  0.0    8.0
# 4  1.6   14.0

# %%
df2.isnull().sum()
# Out:
# fat      0
# carbo    0
# dtype: int64

# %%
df2.describe().transpose()
# Out:
#        count       mean       std  min   25%   50%   75%   max
# fat     77.0   1.092208  1.181298  0.0   0.0   0.9   1.9   5.0
# carbo   77.0  14.597403  4.278956 -1.0  12.0  14.0  17.0  23.0

# %% [markdown]
# The means for fiber and protein are similar, but there are a lot of cereals that apparently have no fiber (note the min and 25% are both 0! That means at least 25% of the cereal have no fiber.  Should consider this, since the amount of variation may be too low to be helpful. Still, the std is twice is high for fiber (relative to the mean), indicating some variation is present. Let's look at the distributions!

# %%
sns.histplot(df2['fat'], kde=True)
# Out:
# <Axes: xlabel='fat', ylabel='Count'>

# %% [markdown]
# Yep: fiber is highly skewed.  Apparently a lot of cereals have NO (or very little) fiber, while a few have a LOT. This explains the high standard deviation (std).
#
# What about protein:

# %%
sns.histplot(df2['carbo'], kde=True)
# Out:
# <Axes: xlabel='carbo', ylabel='Count'>

# %% [markdown]
# The scale is compressed (0 to 7). Relatively few cereals, however, have a lot of protein.  Most have <= 3 grams.

# %% [markdown]
# **Scatterplot**

# %%
plt.title('fat vs. carbo')
plt.xlabel('fat')
plt.ylabel('carbo')
plt.scatter(df['fat'], df['carbo'])
plt.show()

# %% [markdown]
# Scale the data for both fiber and protein.  Run descriptives to confirm that the means are 0 and the standard deviations are 1.

# %%
from sklearn.cluster import KMeans 
from sklearn.preprocessing import scale, StandardScaler

# %%
scaler = StandardScaler() 
scaled_array = scaler.fit_transform(df2)

# %%
fat_average = scaled_array[:,0].mean()
fat_std = scaled_array[:,0].std()
carbo_average=scaled_array[:,1].mean()
carbo_std=scaled_array[:,1].std()

print('fat mean is {:.6f}.'.format(fat_average))
print('fat std is {:.6f}.'.format(fat_std))
print('carbo mean is {:.6f}.'.format(carbo_average))
print('carbo std is {:.6f}.'.format(carbo_std))
# Out:
# fat mean is -0.000000.
# fat std is 1.000000.
# carbo mean is 0.000000.
# carbo std is 1.000000.

# %% [markdown]
# ## Elbow Curve

# %%
wcss=[] 

for i in range(1, 11): 
    kmeans = KMeans(n_clusters=i, init = 'k-means++', random_state = 0) 
    kmeans.fit(scaled_array)  
    wcss.append(kmeans.inertia_) 
    
    
plt.plot(range(1, 11), wcss , 'bx-')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Square')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, random_state = 0) 
kmeans = kmeans.fit(scaled_array)

# %%
unscaled = scaler.inverse_transform(kmeans.cluster_centers_)
unscaled
# Out:
# array([[ 2.16428571, 12.89285714],
#        [ 0.46666667, 19.76190476],
#        [ 1.86666667,  3.66666667],
#        [ 3.9       , 13.66666667],
#        [ 0.45454545, 13.1969697 ]])

# %%
centroids = pd.DataFrame({'centroid_fat':unscaled[:,0],'centroid_carbo':unscaled[:,1]})
centroids
# Out:
#    centroid_fat  centroid_carbo
# 0      2.164286       12.892857
# 1      0.466667       19.761905
# 2      1.866667        3.666667
# 3      3.900000       13.666667
# 4      0.454545       13.196970

# %%
df2['label'] = kmeans.labels_.astype(int) 
df2.head(15)
# Out:
#     fat  carbo  label
# 0   1.3    5.0      2
# 1   5.0    8.0      3
# 2   1.9    7.0      2
# 3   0.0    8.0      4
# 4   1.6   14.0      0
# 5   1.9   10.5      0
# 6   0.0   11.0      4
# 7   1.5   18.0      1
# 8   0.0   15.0      4
# 9   0.6   13.0      4
# 10  2.3   12.0      0
# 11  3.1   17.0      3
# 12  2.1   13.0      0
# 13  2.2   13.0      0
# 14  2.3   12.0      0

# %%
palette1 = {0: 'orange', 1: 'yellow',2:'green', 3:'blue', 4:'black'}
plt.scatter(df2['fat'], df2['carbo'], c=df2['label'].map(palette1)) 
plt.scatter(centroids['centroid_fat'], centroids['centroid_carbo'], c='red')
plt.xlabel('fat')
plt.ylabel('carbo')
plt.show()

# %% [markdown]
# * cluster 0:orange (moderate fiber, moderate protein)
# * cluster 1:yellow (very low fiber, very low protein)
# * cluster 2:green (high fiber, moderate protein)
# * cluster 3:blue (low fiber, low protein)
# * cluster 4:black (low fiber, moderate protein)

# %%
df.head()
# Out:
#                         name mfr  mfrcode type  typecode  calories  protein  \
# 0                  100% Bran   N        4    C         1      70.3      4.3
# 1          100% Natural Bran   Q        6    C         1     120.0      3.0
# 2                   All-Bran   K        3    C         1      70.9      4.9
# 3  All-Bran with Extra Fiber   K        3    C         1      49.3      3.3
# 4             Almond Delight   R        7    C         1     109.6      1.6
#
#    fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0  1.3   130.3   10.3    5.0       6     280        25      3     1.0  0.33
# 1  5.0    15.0    2.0    8.0       8     135         0      3     1.0  1.00
# 2  1.9   260.9    9.9    7.0       5     320        25      3     1.0  0.33
# 3  0.0   139.3   13.3    8.0       0     330        25      3     1.0  0.50
# 4  1.6   199.6    0.6   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
df['label']=df2['label']

# %%
df.head()
# Out:
#                         name mfr  mfrcode type  typecode  calories  protein  \
# 0                  100% Bran   N        4    C         1      70.3      4.3
# 1          100% Natural Bran   Q        6    C         1     120.0      3.0
# 2                   All-Bran   K        3    C         1      70.9      4.9
# 3  All-Bran with Extra Fiber   K        3    C         1      49.3      3.3
# 4             Almond Delight   R        7    C         1     109.6      1.6
#
#    fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0  1.3   130.3   10.3    5.0       6     280        25      3     1.0  0.33
# 1  5.0    15.0    2.0    8.0       8     135         0      3     1.0  1.00
# 2  1.9   260.9    9.9    7.0       5     320        25      3     1.0  0.33
# 3  0.0   139.3   13.3    8.0       0     330        25      3     1.0  0.50
# 4  1.6   199.6    0.6   14.0       8      -1        25      3     1.0  0.75
#
#       rating  label
# 0  68.402973      2
# 1  33.983679      3
# 2  59.425505      2
# 3  93.704912      4
# 4  34.384843      0

# %%
df.loc[df['label']==4]
# Out:
#                          name mfr  mfrcode type  typecode  calories  protein  \
# 3   All-Bran with Extra Fiber   K        3    C         1      49.3      3.3
# 6                 Apple Jacks   K        3    C         1     108.2      0.2
# 8                   Bran Chex   R        7    C         1      88.7      0.7
# 9                 Bran Flakes   P        5    C         1      90.6      3.6
# 17                  Corn Pops   K        3    C         1     109.2      0.2
# 18              Count Chocula   G        2    C         1     109.6      0.6
# 22     Crispy Wheat & Raisins   G        2    C         1     100.2      2.2
# 25             Frosted Flakes   K        3    C         1     108.5      0.0
# 26        Frosted Mini-Wheats   K        3    C         1     101.1      4.1
# 28              Fruitful Bran   K        3    C         1     118.8      1.8
# 29             Fruity Pebbles   P        5    C         1     109.0      0.0
# 30               Golden Crisp   P        5    C         1      98.7      0.7
# 31             Golden Grahams   G        2    C         1     110.3      1.3
# 32          Grape Nuts Flakes   P        5    C         1      99.5      2.5
# 37                 Honey-comb   P        5    C         1     110.9      1.9
# 41                       Life   Q        6    C         1      98.8      2.8
# 42               Lucky Charms   G        2    C         1     109.3      1.3
# 47       Multi-Grain Cheerios   G        2    C         1     100.0      2.0
# 48           Nut&Honey Crunch   K        3    C         1     119.5      1.5
# 52      Post Nat. Raisin Bran   P        5    C         1     119.3      2.3
# 54                Puffed Rice   Q        6    C         1      50.1      1.1
# 55               Puffed Wheat   Q        6    C         1      49.0      1.0
# 56         Quaker Oat Squares   Q        6    C         1      99.3      3.3
# 58                Raisin Bran   K        3    C         1     119.9      2.9
# 59            Raisin Nut Bran   G        2    C         1      99.0      2.0
# 60             Raisin Squares   K        3    C         1      87.8      0.0
# 63             Shredded Wheat   N        4    C         1      81.0      3.0
# 66                     Smacks   K        3    C         1     108.7      0.7
# 67                  Special K   K        3    C         1     109.0      5.0
# 68    Strawberry Fruit Wheats   N        4    C         1      88.3      0.3
# 71          Total Whole Grain   G        2    C         1     100.1      3.1
# 73                       Trix   G        2    C         1     109.6      0.6
# 76        Wheaties Honey Gold   G        2    C         1     109.9      1.9
#
#     fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 3   0.0   139.3   13.3    8.0       0     330        25      3    1.00  0.50
# 6   0.0   123.2    0.0   11.0      14      30        25      2    1.00  1.00
# 8   0.0   198.7    2.7   15.0       6     125        25      1    1.00  0.67
# 9   0.6   210.6    5.6   13.0       5     190        25      3    1.00  0.67
# 17  0.0    89.2    0.2   13.0      12      20        25      2    1.00  1.00
# 18  0.6   179.6    0.0   12.0      13      65        25      2    1.00  1.00
# 22  1.2   140.2    2.2   11.0      10     120        25      3    1.00  0.75
# 25  0.0   198.5    0.0   14.0      11      25        25      1    1.00  0.75
# 26  1.1     1.1    4.1   14.0       7     100        25      2    1.00  0.80
# 28  0.0   238.8    3.8   14.0      12     190        25      3    1.33  0.67
# 29  0.0   134.0    0.0   13.0      12      25        25      2    1.00  0.75
# 30  0.0    43.7    0.0   11.0      15      40        25      1    1.00  0.88
# 31  1.3   280.3    0.3   15.0       9      45        25      2    1.00  0.75
# 32  0.5   139.5    2.5   15.0       5      85        25      3    1.00  0.88
# 37  0.9   180.9    0.9   14.0      11      35        25      1    1.00  1.33
# 41  0.8   148.8    0.8   12.0       6      95        25      2    1.00  0.67
# 42  0.3   179.3    0.0   12.0      12      55        25      2    1.00  1.00
# 47  1.0   220.0    2.0   15.0       6      90        25      1    1.00  1.00
# 48  0.5   189.5    0.0   15.0       9      40        25      2    1.00  0.67
# 52  0.3   199.3    5.3   11.0      14     260        25      3    1.33  0.67
# 54  0.1     0.1    0.1   13.0       0      15         0      3    0.50  1.00
# 55  0.0     0.0    0.0   10.0       0      50         0      3    0.50  1.00
# 56  0.3   134.3    1.3   14.0       6     110        25      3    1.00  0.50
# 58  0.9   209.9    4.9   14.0      12     240        25      2    1.33  0.75
# 59  1.0   139.0    1.5   10.5       8     140        25      3    1.00  0.50
# 60  0.0     0.0    0.0   15.0       6     110        25      3    1.00  0.50
# 63  1.0     1.0    4.0   16.0       0      95         0      1    0.83  1.00
# 66  0.0    68.7    0.0    9.0      15      40        25      2    1.00  0.75
# 67  0.0   229.0    0.0   16.0       3      55        25      1    1.00  1.00
# 68  0.0    13.3    1.3   15.0       5      90        25      2    1.00  1.00
# 71  1.1   200.1    3.1   16.0       3     110       100      3    1.00  1.00
# 73  0.6   139.6    0.0   13.0      12      25        25      2    1.00  1.00
# 76  0.9   199.9    0.9   16.0       8      60        25      1    1.00  0.75
#
#        rating  label
# 3   93.704912      4
# 6   33.174094      4
# 8   49.120253      4
# 9   53.313813      4
# 17  35.782791      4
# 18  22.396513      4
# 22  36.176196      4
# 25  31.435973      4
# 26  58.345141      4
# 28  41.015492      4
# 29  28.025765      4
# 30  35.252444      4
# 31  23.804043      4
# 32  52.076897      4
# 37  28.742414      4
# 41  45.328074      4
# 42  26.734515      4
# 47  40.105965      4
# 48  29.924285      4
# 52  37.840594      4
# 54  60.756112      4
# 55  63.005645      4
# 56  49.511874      4
# 58  39.259197      4
# 59  39.703400      4
# 60  55.333142      4
# 63  68.235885      4
# 66  31.230054      4
# 67  53.131324      4
# 68  59.363993      4
# 71  46.658844      4
# 73  27.753301      4
# 76  36.187559      4

# %%
df['label'].value_counts()
# Out:
# 4    33
# 1    21
# 0    14
# 3     6
# 2     3
# Name: label, dtype: int64

# %%
df['label'].value_counts().sort_index()
# Out:
# 0    14
# 1    21
# 2     3
# 3     6
# 4    33
# Name: label, dtype: int64
